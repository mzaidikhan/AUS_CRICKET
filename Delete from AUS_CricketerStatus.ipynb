# %%
#First empty AUS_CricketerStatus
spark.sql("DROP TABLE IF EXISTS AUS_CricketerStatus")
# Out:
# StatementMeta(, 9ffde2e8-b4ec-488c-8764-81b67832956f, 3, Finished, Available, Finished)
# DataFrame[]
