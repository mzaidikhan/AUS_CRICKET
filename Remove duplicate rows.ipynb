# %%
df = spark.sql("SELECT * FROM AUS_CRICKET_LAKEHOUSE.dbo.aus_cricketerstatus LIMIT 1000")
display(df)
#Remove duplicate rows
df.drop_duplicates(subset=['id', 'season_id','type'])
display(df)
# Out:
# StatementMeta(, 515091ba-670a-487b-91c7-f379bb3002f9, 10, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, da986774-4efe-4d18-bc94-01cab39dda53)
# SynapseWidget(Synapse.DataFrame, b93826ae-71a2-4967-9284-3f16feafe67c)
