# %%
spark.sql("DROP TABLE IF EXISTS FACT_CricketerStats")
spark.sql("DROP TABLE IF EXISTS DimCustomCalendar")
# Out:
# StatementMeta(, 852b1f4f-76dc-4345-a4f2-b4df7241a824, 5, Finished, Available, Finished)
# DataFrame[]
